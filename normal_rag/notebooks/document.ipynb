# %% [markdown]
# ## Document Structure

# %%
from langchain_core.documents import Document
import dill

# %%
doc=Document(
    page_content="this is the main text content I am using to create RAG",
    metadata={
        "source":"exmaple.txt",
        "pages":1,
        "author":"Rafid Ahmed",
        "date_created":"2025-01-01"
    }
)
doc
# Out:
# Document(metadata={'source': 'exmaple.txt', 'pages': 1, 'author': 'Rafid Ahmed', 'date_created': '2025-01-01'}, page_content='this is the main text content I am using to create RAG')

# %%
## Create a simple txt file
import os
os.makedirs("../data/text_files",exist_ok=True)

# %%
sample_texts={
    "../data/text_files/python_intro.txt":"""Python Programming Introduction

Python is a high-level, interpreted programming language known for its simplicity and readability.
Created by Guido van Rossum and first released in 1991, Python has become one of the most popular
programming languages in the world.

Key Features:
- Easy to learn and use
- Extensive standard library
- Cross-platform compatibility
- Strong community support

Python is widely used in web development, data science, artificial intelligence, and automation.""",
    
    "../data/text_files/machine_learning.txt": """Machine Learning Basics

Machine learning is a subset of artificial intelligence that enables systems to learn and improve
from experience without being explicitly programmed. It focuses on developing computer programs
that can access data and use it to learn for themselves.

Types of Machine Learning:
1. Supervised Learning: Learning with labeled data
2. Unsupervised Learning: Finding patterns in unlabeled data
3. Reinforcement Learning: Learning through rewards and penalties

Applications include image recognition, speech processing, and recommendation systems
    
    
    """

}

for filepath,content in sample_texts.items():
    with open(filepath,'w',encoding="utf-8") as f:
        f.write(content)

print("✅ Sample text files created!")
# Out:
# ✅ Sample text files created!

# %% [markdown]
# ## Text Loader

# %%
from langchain_community.document_loaders import TextLoader
loader=TextLoader("../data/text_files/python_intro.txt",encoding="utf-8")
documents=loader.load()
print(documents)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader
from langchain_community.document_loaders import DirectoryLoader

## load all the text files from the directory
dir_loader=DirectoryLoader(
    "../data/pdf",
    glob="**/*.pdf", ## Pattern to match files  
    loader_cls= PyMuPDFLoader, ##loader class to use
    show_progress=False

)

pdf_documents=dir_loader.load()
pdf_documents
# Out:
# [Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-10-28T12:02:30+00:00', 'source': '../data/pdf/dp_presentation.pdf', 'file_path': '../data/pdf/dp_presentation.pdf', 'total_pages': 19, 'format': 'PDF 1.4', 'title': 'DP presentation', 'author': 'Sadman Sahil', 'subject': '', 'keywords': 'DAG2hyVnXFs,BAGndFZHqL4,0', 'moddate': '2025-10-28T12:02:29+00:00', 'trapped': '', 'modDate': "D:20251028120229+00'00'", 'creationDate': "D:20251028120230+00'00'", 'page': 0}, page_content='Introduction \nMany modern apps and speech-based systems collect\nand process users’ voice data.\nThis voice data often contains personal or sensitive\ninformation.\nWithout proper protection, attackers can misuse it to\nsteal identities or gain unauthorized access.\n3'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-10-28T12:02:30+00:00', 'source': '../data/pdf/dp_presentation.pdf', 'file_path': '../data/pdf/dp_presentation.pdf', 'total_pages': 19, 'format': 'PDF 1.4', 'title': 'DP presentation', 'author': 'Sadman Sahil', 'subject': '', 'keywords': 'DAG2hyVnXFs,BAGndFZHqL4,0', 'moddate': '2025-10-28T12:02:29+00:00', 'trapped': '', 'modDate': "D:20251028120229+00'00'", 'creationDate': "D:20251028120230+00'00'", 'page': 1}, page_content='Domain Introduction\nAudio Anonymization:\nHides or masks the\nspeaker’s identity while\nkeeping the spoken\ncontent clear and\nunderstandable.\nAudio Encryption:\nScrambles the entire\naudio so it becomes\ncompletely unreadable\nwithout decryption.\nUse Case: \nEnables safe sharing of\nspeech data for daily life\nusage, research or AI\nconversion without\nrevealing who spoke.\n4'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-10-28T12:02:30+00:00', 'source': '../data/pdf/dp_presentation.pdf', 'file_path': '../data/pdf/dp_presentation.pdf', 'total_pages': 19, 'format': 'PDF 1.4', 'title': 'DP presentation', 'author': 'Sadman Sahil', 'subject': '', 'keywords': 'DAG2hyVnXFs,BAGndFZHqL4,0', 'moddate': '2025-10-28T12:02:29+00:00', 'trapped': '', 'modDate': "D:20251028120229+00'00'", 'creationDate': "D:20251028120230+00'00'", 'page': 2}, page_content='Literature\nReview\n5'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-10-28T12:02:30+00:00', 'source': '../data/pdf/dp_presentation.pdf', 'file_path': '../data/pdf/dp_presentation.pdf', 'total_pages': 19, 'format': 'PDF 1.4', 'title': 'DP presentation', 'author': 'Sadman Sahil', 'subject': '', 'keywords': 'DAG2hyVnXFs,BAGndFZHqL4,0', 'moddate': '2025-10-28T12:02:29+00:00', 'trapped': '', 'modDate': "D:20251028120229+00'00'", 'creationDate': "D:20251028120230+00'00'", 'page': 3}, page_content='The VoicePrivacy 2022 Challenge: Progress &\nPerspectives in Voice Anonymisation\nAuthors: Pierre Champion, Nicholas Evans, Sarina Meyer, Xiaoxiao Miao, Michele\nPanariello, Massimiliano Todisco, Natalia Tomashenko, Emmanuel Vincent, Xin Wang,\nJunichi Yamagishi\nPublication Date: 16 July, 2024\nPublication: IEEE/ACM Transactions on Audio, Speech and Language\nProcessing\nAffiliation: EURECOM, France; Inria, France; University of Stuttgart,\nGermany\nPaper 1\n6'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-10-28T12:02:30+00:00', 'source': '../data/pdf/dp_presentation.pdf', 'file_path': '../data/pdf/dp_presentation.pdf', 'total_pages': 19, 'format': 'PDF 1.4', 'title': 'DP presentation', 'author': 'Sadman Sahil', 'subject': '', 'keywords': 'DAG2hyVnXFs,BAGndFZHqL4,0', 'moddate': '2025-10-28T12:02:29+00:00', 'trapped': '', 'modDate': "D:20251028120229+00'00'", 'creationDate': "D:20251028120230+00'00'", 'page': 4}, page_content='The VoicePrivacy 2022 Challenge: Progress &\nPerspectives in Voice Anonymisation\nThis paper summarizes the VoicePrivacy 2022 Challenge, which evaluates\ntechniques for anonymizing a speaker’s identity in speech. \nIt compares different anonymization approaches and shows a trade-off\nbetween privacy and speech quality. \nAchieving both strong privacy and high naturalness remains unsolved\n7'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-10-28T12:02:30+00:00', 'source': '../data/pdf/dp_presentation.pdf', 'file_path': '../data/pdf/dp_presentation.pdf', 'total_pages': 19, 'format': 'PDF 1.4', 'title': 'DP presentation', 'author': 'Sadman Sahil', 'subject': '', 'keywords': 'DAG2hyVnXFs,BAGndFZHqL4,0', 'moddate': '2025-10-28T12:02:29+00:00', 'trapped': '', 'modDate': "D:20251028120229+00'00'", 'creationDate': "D:20251028120230+00'00'", 'page': 5}, page_content='The VoicePrivacy 2022 Challenge: Progress &\nPerspectives in Voice Anonymisation\nX-vector & ECPA to extract speaker identity\nGenerate pseudo-speaker embedding with GAN\nSpeech is resynthesized with TTS and HiFi-GAN\nExcellent privacy and good utility but loses pitch change\nrequirement\n8'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-10-28T12:02:30+00:00', 'source': '../data/pdf/dp_presentation.pdf', 'file_path': '../data/pdf/dp_presentation.pdf', 'total_pages': 19, 'format': 'PDF 1.4', 'title': 'DP presentation', 'author': 'Sadman Sahil', 'subject': '', 'keywords': 'DAG2hyVnXFs,BAGndFZHqL4,0', 'moddate': '2025-10-28T12:02:29+00:00', 'trapped': '', 'modDate': "D:20251028120229+00'00'", 'creationDate': "D:20251028120230+00'00'", 'page': 6}, page_content='The VoicePrivacy 2022 Challenge: Progress &\nPerspectives in Voice Anonymisation\nScope\nDataset (multiple Speaker + bigger & more diverse dataset)\nTradeoff between EER & WER\nHuman Vs Machine Understanding\n9'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-10-28T12:02:30+00:00', 'source': '../data/pdf/dp_presentation.pdf', 'file_path': '../data/pdf/dp_presentation.pdf', 'total_pages': 19, 'format': 'PDF 1.4', 'title': 'DP presentation', 'author': 'Sadman Sahil', 'subject': '', 'keywords': 'DAG2hyVnXFs,BAGndFZHqL4,0', 'moddate': '2025-10-28T12:02:29+00:00', 'trapped': '', 'modDate': "D:20251028120229+00'00'", 'creationDate': "D:20251028120230+00'00'", 'page': 7}, page_content='X-vector anonymization using autoencoders &\nadversarial training for preserving speech privacy\nAuthors: Juan M. Perero-Codosero, Fernando M. Espinoza-Cuadros, Luis A. Hernández-\nGómez\nAffiliation: Sigma Technologies S.L.U., Madrid, Spain .\n GAPS Signal Processing Applications Group, Universidad Politécnica de Madrid, Madrid,\nSpain\nPublished in:  Computer Speech & Language\nPublication Date: January 2022\nPaper 2\n10'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-10-28T12:02:30+00:00', 'source': '../data/pdf/dp_presentation.pdf', 'file_path': '../data/pdf/dp_presentation.pdf', 'total_pages': 19, 'format': 'PDF 1.4', 'title': 'DP presentation', 'author': 'Sadman Sahil', 'subject': '', 'keywords': 'DAG2hyVnXFs,BAGndFZHqL4,0', 'moddate': '2025-10-28T12:02:29+00:00', 'trapped': '', 'modDate': "D:20251028120229+00'00'", 'creationDate': "D:20251028120230+00'00'", 'page': 8}, page_content='X-vector anonymization using autoencoders &\nadversarial training for preserving speech privacy\nStep 1: Feature Extraction\nX-vector: A digital "voiceprint" (embedding vector)  that captures who you are.\nF0 (Fundamental Frequency): Your voice\'s pitch\nLinguistic content: What words/sounds you\'re saying\nStep 2: Anonymize the X-vector → AAN (Autoencoder-Adversarial Network).\nAutoencoder : Tries to compress and reconstruct the x-vector\nAdverserial Training : Tries to erase identifying info like:\na.Specific speaker identity\nb.Gender\nc.Accent\n11'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-10-28T12:02:30+00:00', 'source': '../data/pdf/dp_presentation.pdf', 'file_path': '../data/pdf/dp_presentation.pdf', 'total_pages': 19, 'format': 'PDF 1.4', 'title': 'DP presentation', 'author': 'Sadman Sahil', 'subject': '', 'keywords': 'DAG2hyVnXFs,BAGndFZHqL4,0', 'moddate': '2025-10-28T12:02:29+00:00', 'trapped': '', 'modDate': "D:20251028120229+00'00'", 'creationDate': "D:20251028120230+00'00'", 'page': 9}, page_content='X-vector anonymization using autoencoders &\nadversarial training for preserving speech privacy\nStep 3: Generate New Anonymous Speech\nThe system uses:\nThe anonymized x-vector (the identity)\nOriginal pitch (F0)\nOriginal Words (linguistic content)\nTo create new speech that says the same thing but sounds like a different person\n12'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-10-28T12:02:30+00:00', 'source': '../data/pdf/dp_presentation.pdf', 'file_path': '../data/pdf/dp_presentation.pdf', 'total_pages': 19, 'format': 'PDF 1.4', 'title': 'DP presentation', 'author': 'Sadman Sahil', 'subject': '', 'keywords': 'DAG2hyVnXFs,BAGndFZHqL4,0', 'moddate': '2025-10-28T12:02:29+00:00', 'trapped': '', 'modDate': "D:20251028120229+00'00'", 'creationDate': "D:20251028120230+00'00'", 'page': 10}, page_content='X-vector anonymization using autoencoders &\nadversarial training for preserving speech privacy\n13\nResults\nThe paper compares its system to the "Baseline" system and other systems from the\nVoicePrivacy 2020 Challenge \nPrivacy (EER): The paper\'s system achieved a very high EER (37.8%) in the main test scenario\nThis was better (more private) than the Baseline (31.9%) and most other systems.\nIntelligibility (WER): The paper\'s system had a Word Error Rate (WER) of 11.0%. This was\npractically the same as the Baseline (10.9%) and the other systems.'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-10-28T12:02:30+00:00', 'source': '../data/pdf/dp_presentation.pdf', 'file_path': '../data/pdf/dp_presentation.pdf', 'total_pages': 19, 'format': 'PDF 1.4', 'title': 'DP presentation', 'author': 'Sadman Sahil', 'subject': '', 'keywords': 'DAG2hyVnXFs,BAGndFZHqL4,0', 'moddate': '2025-10-28T12:02:29+00:00', 'trapped': '', 'modDate': "D:20251028120229+00'00'", 'creationDate': "D:20251028120230+00'00'", 'page': 11}, page_content='X-vector anonymization using autoencoders &\nadversarial training for preserving speech privacy\n14\nFuture Scope\nMore speaker characteristics for anonymization:\nCurrently, they anonymize speaker identity, gender, and accent.\nIn the future, they aim to include more characteristics like emotion, age, or speaking\nstyle.\nBetter anonymization of the full speech waveform:\nThe current system anonymizes the x-vector (speaker embedding) but not the full speech\nwaveform.\nIn the future, they plan to apply the method directly to encoded speech and prosodic features\n(like rhythm and intonation) for deeper anonymization.'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-10-28T12:02:30+00:00', 'source': '../data/pdf/dp_presentation.pdf', 'file_path': '../data/pdf/dp_presentation.pdf', 'total_pages': 19, 'format': 'PDF 1.4', 'title': 'DP presentation', 'author': 'Sadman Sahil', 'subject': '', 'keywords': 'DAG2hyVnXFs,BAGndFZHqL4,0', 'moddate': '2025-10-28T12:02:29+00:00', 'trapped': '', 'modDate': "D:20251028120229+00'00'", 'creationDate': "D:20251028120230+00'00'", 'page': 12}, page_content='Quantized Approximate Signal Processing\n(QASP): Towards Homomorphic Encryption for\naudio\nAuthors: Tu Duyen Nguyen, Adrien Lesage, Clotilde Cantini, Rachid Riad\nPublication Date: submitted on 15 May 2025,  to\nComputer Speech & Language\nAffiliation:  Callyope, a medical copilot AI company in Paris,\nFrance.\nPaper 3\n15'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-10-28T12:02:30+00:00', 'source': '../data/pdf/dp_presentation.pdf', 'file_path': '../data/pdf/dp_presentation.pdf', 'total_pages': 19, 'format': 'PDF 1.4', 'title': 'DP presentation', 'author': 'Sadman Sahil', 'subject': '', 'keywords': 'DAG2hyVnXFs,BAGndFZHqL4,0', 'moddate': '2025-10-28T12:02:29+00:00', 'trapped': '', 'modDate': "D:20251028120229+00'00'", 'creationDate': "D:20251028120230+00'00'", 'page': 13}, page_content='Homomorphic Encryption (HE)\nA cryptographic method that allows computations on encrypted data. \nCan perform calculations on it without decryption.\nThe server sees only encrypted file, but can still run functions (e.g., ML,\nstatistics, MFCC, Mel-Spectogram)\nAfter computation, the result is decrypted by the owner and matches the\noutput as if it was computed on original file.\n16'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-10-28T12:02:30+00:00', 'source': '../data/pdf/dp_presentation.pdf', 'file_path': '../data/pdf/dp_presentation.pdf', 'total_pages': 19, 'format': 'PDF 1.4', 'title': 'DP presentation', 'author': 'Sadman Sahil', 'subject': '', 'keywords': 'DAG2hyVnXFs,BAGndFZHqL4,0', 'moddate': '2025-10-28T12:02:29+00:00', 'trapped': '', 'modDate': "D:20251028120229+00'00'", 'creationDate': "D:20251028120230+00'00'", 'page': 14}, page_content='Homomorphic Encryption (HE)\n17'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-10-28T12:02:30+00:00', 'source': '../data/pdf/dp_presentation.pdf', 'file_path': '../data/pdf/dp_presentation.pdf', 'total_pages': 19, 'format': 'PDF 1.4', 'title': 'DP presentation', 'author': 'Sadman Sahil', 'subject': '', 'keywords': 'DAG2hyVnXFs,BAGndFZHqL4,0', 'moddate': '2025-10-28T12:02:29+00:00', 'trapped': '', 'modDate': "D:20251028120229+00'00'", 'creationDate': "D:20251028120230+00'00'", 'page': 15}, page_content='Limitations of Fully Homomorphic\nEncryption (FHE)\nFully Homomorphic Encryption only allows computation on low-bit integers\n(usually <= 16 bits)\nStandard audio processing (STFT, Mel, MFCC) uses floating-point math and produces\nlarge intermediate values inexecutable inside HE. \nSo direct manipulations (MFCC , Mels ) on encrypted audio would cause\n        overflow.\nIt adds noise after every operation as can not calculate exact precision value and has\nhigher computational cost.\n18'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-10-28T12:02:30+00:00', 'source': '../data/pdf/dp_presentation.pdf', 'file_path': '../data/pdf/dp_presentation.pdf', 'total_pages': 19, 'format': 'PDF 1.4', 'title': 'DP presentation', 'author': 'Sadman Sahil', 'subject': '', 'keywords': 'DAG2hyVnXFs,BAGndFZHqL4,0', 'moddate': '2025-10-28T12:02:29+00:00', 'trapped': '', 'modDate': "D:20251028120229+00'00'", 'creationDate': "D:20251028120230+00'00'", 'page': 16}, page_content='QASP (Quantized Approximate Signal\nProcessing)\n It basically converts the high presition continuous audio data to discrete low bit\nformat.\nDoes this By Quantization basically discretization of values so that higher\ncalculations done easily\nPreserve only the necessary audio structure for downstream tasks.\nThis discretization is achieved through agressive Quantization.\n19'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-10-28T12:02:30+00:00', 'source': '../data/pdf/dp_presentation.pdf', 'file_path': '../data/pdf/dp_presentation.pdf', 'total_pages': 19, 'format': 'PDF 1.4', 'title': 'DP presentation', 'author': 'Sadman Sahil', 'subject': '', 'keywords': 'DAG2hyVnXFs,BAGndFZHqL4,0', 'moddate': '2025-10-28T12:02:29+00:00', 'trapped': '', 'modDate': "D:20251028120229+00'00'", 'creationDate': "D:20251028120230+00'00'", 'page': 17}, page_content='Future Scope\n20'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-10-28T12:02:30+00:00', 'source': '../data/pdf/dp_presentation.pdf', 'file_path': '../data/pdf/dp_presentation.pdf', 'total_pages': 19, 'format': 'PDF 1.4', 'title': 'DP presentation', 'author': 'Sadman Sahil', 'subject': '', 'keywords': 'DAG2hyVnXFs,BAGndFZHqL4,0', 'moddate': '2025-10-28T12:02:29+00:00', 'trapped': '', 'modDate': "D:20251028120229+00'00'", 'creationDate': "D:20251028120230+00'00'", 'page': 18}, page_content='Possible Future Approach\nAnonymize the audio while keeping the privacy intact(tradeoff of EER & WER)\nExplore Homomorphic encryption technology\nKeep a key to reverse back to original version from anonymized one\n21')]

# %%
type(pdf_documents[0])
# Out:
# langchain_core.documents.base.Document

# %%
import pickle
with open('documents.pkl', 'wb') as f:
    pickle.dump(pdf_documents, f)

# %%
import pickle
with open('documents.pkl', 'rb') as f:
    pdf_documents = pickle.load(f)

# %%
pdf_documents
# Out:
# [Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-10-28T12:02:30+00:00', 'source': '../data/pdf/dp_presentation.pdf', 'file_path': '../data/pdf/dp_presentation.pdf', 'total_pages': 19, 'format': 'PDF 1.4', 'title': 'DP presentation', 'author': 'Sadman Sahil', 'subject': '', 'keywords': 'DAG2hyVnXFs,BAGndFZHqL4,0', 'moddate': '2025-10-28T12:02:29+00:00', 'trapped': '', 'modDate': "D:20251028120229+00'00'", 'creationDate': "D:20251028120230+00'00'", 'page': 0}, page_content='Introduction \nMany modern apps and speech-based systems collect\nand process users’ voice data.\nThis voice data often contains personal or sensitive\ninformation.\nWithout proper protection, attackers can misuse it to\nsteal identities or gain unauthorized access.\n3'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-10-28T12:02:30+00:00', 'source': '../data/pdf/dp_presentation.pdf', 'file_path': '../data/pdf/dp_presentation.pdf', 'total_pages': 19, 'format': 'PDF 1.4', 'title': 'DP presentation', 'author': 'Sadman Sahil', 'subject': '', 'keywords': 'DAG2hyVnXFs,BAGndFZHqL4,0', 'moddate': '2025-10-28T12:02:29+00:00', 'trapped': '', 'modDate': "D:20251028120229+00'00'", 'creationDate': "D:20251028120230+00'00'", 'page': 1}, page_content='Domain Introduction\nAudio Anonymization:\nHides or masks the\nspeaker’s identity while\nkeeping the spoken\ncontent clear and\nunderstandable.\nAudio Encryption:\nScrambles the entire\naudio so it becomes\ncompletely unreadable\nwithout decryption.\nUse Case: \nEnables safe sharing of\nspeech data for daily life\nusage, research or AI\nconversion without\nrevealing who spoke.\n4'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-10-28T12:02:30+00:00', 'source': '../data/pdf/dp_presentation.pdf', 'file_path': '../data/pdf/dp_presentation.pdf', 'total_pages': 19, 'format': 'PDF 1.4', 'title': 'DP presentation', 'author': 'Sadman Sahil', 'subject': '', 'keywords': 'DAG2hyVnXFs,BAGndFZHqL4,0', 'moddate': '2025-10-28T12:02:29+00:00', 'trapped': '', 'modDate': "D:20251028120229+00'00'", 'creationDate': "D:20251028120230+00'00'", 'page': 2}, page_content='Literature\nReview\n5'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-10-28T12:02:30+00:00', 'source': '../data/pdf/dp_presentation.pdf', 'file_path': '../data/pdf/dp_presentation.pdf', 'total_pages': 19, 'format': 'PDF 1.4', 'title': 'DP presentation', 'author': 'Sadman Sahil', 'subject': '', 'keywords': 'DAG2hyVnXFs,BAGndFZHqL4,0', 'moddate': '2025-10-28T12:02:29+00:00', 'trapped': '', 'modDate': "D:20251028120229+00'00'", 'creationDate': "D:20251028120230+00'00'", 'page': 3}, page_content='The VoicePrivacy 2022 Challenge: Progress &\nPerspectives in Voice Anonymisation\nAuthors: Pierre Champion, Nicholas Evans, Sarina Meyer, Xiaoxiao Miao, Michele\nPanariello, Massimiliano Todisco, Natalia Tomashenko, Emmanuel Vincent, Xin Wang,\nJunichi Yamagishi\nPublication Date: 16 July, 2024\nPublication: IEEE/ACM Transactions on Audio, Speech and Language\nProcessing\nAffiliation: EURECOM, France; Inria, France; University of Stuttgart,\nGermany\nPaper 1\n6'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-10-28T12:02:30+00:00', 'source': '../data/pdf/dp_presentation.pdf', 'file_path': '../data/pdf/dp_presentation.pdf', 'total_pages': 19, 'format': 'PDF 1.4', 'title': 'DP presentation', 'author': 'Sadman Sahil', 'subject': '', 'keywords': 'DAG2hyVnXFs,BAGndFZHqL4,0', 'moddate': '2025-10-28T12:02:29+00:00', 'trapped': '', 'modDate': "D:20251028120229+00'00'", 'creationDate': "D:20251028120230+00'00'", 'page': 4}, page_content='The VoicePrivacy 2022 Challenge: Progress &\nPerspectives in Voice Anonymisation\nThis paper summarizes the VoicePrivacy 2022 Challenge, which evaluates\ntechniques for anonymizing a speaker’s identity in speech. \nIt compares different anonymization approaches and shows a trade-off\nbetween privacy and speech quality. \nAchieving both strong privacy and high naturalness remains unsolved\n7'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-10-28T12:02:30+00:00', 'source': '../data/pdf/dp_presentation.pdf', 'file_path': '../data/pdf/dp_presentation.pdf', 'total_pages': 19, 'format': 'PDF 1.4', 'title': 'DP presentation', 'author': 'Sadman Sahil', 'subject': '', 'keywords': 'DAG2hyVnXFs,BAGndFZHqL4,0', 'moddate': '2025-10-28T12:02:29+00:00', 'trapped': '', 'modDate': "D:20251028120229+00'00'", 'creationDate': "D:20251028120230+00'00'", 'page': 5}, page_content='The VoicePrivacy 2022 Challenge: Progress &\nPerspectives in Voice Anonymisation\nX-vector & ECPA to extract speaker identity\nGenerate pseudo-speaker embedding with GAN\nSpeech is resynthesized with TTS and HiFi-GAN\nExcellent privacy and good utility but loses pitch change\nrequirement\n8'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-10-28T12:02:30+00:00', 'source': '../data/pdf/dp_presentation.pdf', 'file_path': '../data/pdf/dp_presentation.pdf', 'total_pages': 19, 'format': 'PDF 1.4', 'title': 'DP presentation', 'author': 'Sadman Sahil', 'subject': '', 'keywords': 'DAG2hyVnXFs,BAGndFZHqL4,0', 'moddate': '2025-10-28T12:02:29+00:00', 'trapped': '', 'modDate': "D:20251028120229+00'00'", 'creationDate': "D:20251028120230+00'00'", 'page': 6}, page_content='The VoicePrivacy 2022 Challenge: Progress &\nPerspectives in Voice Anonymisation\nScope\nDataset (multiple Speaker + bigger & more diverse dataset)\nTradeoff between EER & WER\nHuman Vs Machine Understanding\n9'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-10-28T12:02:30+00:00', 'source': '../data/pdf/dp_presentation.pdf', 'file_path': '../data/pdf/dp_presentation.pdf', 'total_pages': 19, 'format': 'PDF 1.4', 'title': 'DP presentation', 'author': 'Sadman Sahil', 'subject': '', 'keywords': 'DAG2hyVnXFs,BAGndFZHqL4,0', 'moddate': '2025-10-28T12:02:29+00:00', 'trapped': '', 'modDate': "D:20251028120229+00'00'", 'creationDate': "D:20251028120230+00'00'", 'page': 7}, page_content='X-vector anonymization using autoencoders &\nadversarial training for preserving speech privacy\nAuthors: Juan M. Perero-Codosero, Fernando M. Espinoza-Cuadros, Luis A. Hernández-\nGómez\nAffiliation: Sigma Technologies S.L.U., Madrid, Spain .\n GAPS Signal Processing Applications Group, Universidad Politécnica de Madrid, Madrid,\nSpain\nPublished in:  Computer Speech & Language\nPublication Date: January 2022\nPaper 2\n10'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-10-28T12:02:30+00:00', 'source': '../data/pdf/dp_presentation.pdf', 'file_path': '../data/pdf/dp_presentation.pdf', 'total_pages': 19, 'format': 'PDF 1.4', 'title': 'DP presentation', 'author': 'Sadman Sahil', 'subject': '', 'keywords': 'DAG2hyVnXFs,BAGndFZHqL4,0', 'moddate': '2025-10-28T12:02:29+00:00', 'trapped': '', 'modDate': "D:20251028120229+00'00'", 'creationDate': "D:20251028120230+00'00'", 'page': 8}, page_content='X-vector anonymization using autoencoders &\nadversarial training for preserving speech privacy\nStep 1: Feature Extraction\nX-vector: A digital "voiceprint" (embedding vector)  that captures who you are.\nF0 (Fundamental Frequency): Your voice\'s pitch\nLinguistic content: What words/sounds you\'re saying\nStep 2: Anonymize the X-vector → AAN (Autoencoder-Adversarial Network).\nAutoencoder : Tries to compress and reconstruct the x-vector\nAdverserial Training : Tries to erase identifying info like:\na.Specific speaker identity\nb.Gender\nc.Accent\n11'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-10-28T12:02:30+00:00', 'source': '../data/pdf/dp_presentation.pdf', 'file_path': '../data/pdf/dp_presentation.pdf', 'total_pages': 19, 'format': 'PDF 1.4', 'title': 'DP presentation', 'author': 'Sadman Sahil', 'subject': '', 'keywords': 'DAG2hyVnXFs,BAGndFZHqL4,0', 'moddate': '2025-10-28T12:02:29+00:00', 'trapped': '', 'modDate': "D:20251028120229+00'00'", 'creationDate': "D:20251028120230+00'00'", 'page': 9}, page_content='X-vector anonymization using autoencoders &\nadversarial training for preserving speech privacy\nStep 3: Generate New Anonymous Speech\nThe system uses:\nThe anonymized x-vector (the identity)\nOriginal pitch (F0)\nOriginal Words (linguistic content)\nTo create new speech that says the same thing but sounds like a different person\n12'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-10-28T12:02:30+00:00', 'source': '../data/pdf/dp_presentation.pdf', 'file_path': '../data/pdf/dp_presentation.pdf', 'total_pages': 19, 'format': 'PDF 1.4', 'title': 'DP presentation', 'author': 'Sadman Sahil', 'subject': '', 'keywords': 'DAG2hyVnXFs,BAGndFZHqL4,0', 'moddate': '2025-10-28T12:02:29+00:00', 'trapped': '', 'modDate': "D:20251028120229+00'00'", 'creationDate': "D:20251028120230+00'00'", 'page': 10}, page_content='X-vector anonymization using autoencoders &\nadversarial training for preserving speech privacy\n13\nResults\nThe paper compares its system to the "Baseline" system and other systems from the\nVoicePrivacy 2020 Challenge \nPrivacy (EER): The paper\'s system achieved a very high EER (37.8%) in the main test scenario\nThis was better (more private) than the Baseline (31.9%) and most other systems.\nIntelligibility (WER): The paper\'s system had a Word Error Rate (WER) of 11.0%. This was\npractically the same as the Baseline (10.9%) and the other systems.'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-10-28T12:02:30+00:00', 'source': '../data/pdf/dp_presentation.pdf', 'file_path': '../data/pdf/dp_presentation.pdf', 'total_pages': 19, 'format': 'PDF 1.4', 'title': 'DP presentation', 'author': 'Sadman Sahil', 'subject': '', 'keywords': 'DAG2hyVnXFs,BAGndFZHqL4,0', 'moddate': '2025-10-28T12:02:29+00:00', 'trapped': '', 'modDate': "D:20251028120229+00'00'", 'creationDate': "D:20251028120230+00'00'", 'page': 11}, page_content='X-vector anonymization using autoencoders &\nadversarial training for preserving speech privacy\n14\nFuture Scope\nMore speaker characteristics for anonymization:\nCurrently, they anonymize speaker identity, gender, and accent.\nIn the future, they aim to include more characteristics like emotion, age, or speaking\nstyle.\nBetter anonymization of the full speech waveform:\nThe current system anonymizes the x-vector (speaker embedding) but not the full speech\nwaveform.\nIn the future, they plan to apply the method directly to encoded speech and prosodic features\n(like rhythm and intonation) for deeper anonymization.'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-10-28T12:02:30+00:00', 'source': '../data/pdf/dp_presentation.pdf', 'file_path': '../data/pdf/dp_presentation.pdf', 'total_pages': 19, 'format': 'PDF 1.4', 'title': 'DP presentation', 'author': 'Sadman Sahil', 'subject': '', 'keywords': 'DAG2hyVnXFs,BAGndFZHqL4,0', 'moddate': '2025-10-28T12:02:29+00:00', 'trapped': '', 'modDate': "D:20251028120229+00'00'", 'creationDate': "D:20251028120230+00'00'", 'page': 12}, page_content='Quantized Approximate Signal Processing\n(QASP): Towards Homomorphic Encryption for\naudio\nAuthors: Tu Duyen Nguyen, Adrien Lesage, Clotilde Cantini, Rachid Riad\nPublication Date: submitted on 15 May 2025,  to\nComputer Speech & Language\nAffiliation:  Callyope, a medical copilot AI company in Paris,\nFrance.\nPaper 3\n15'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-10-28T12:02:30+00:00', 'source': '../data/pdf/dp_presentation.pdf', 'file_path': '../data/pdf/dp_presentation.pdf', 'total_pages': 19, 'format': 'PDF 1.4', 'title': 'DP presentation', 'author': 'Sadman Sahil', 'subject': '', 'keywords': 'DAG2hyVnXFs,BAGndFZHqL4,0', 'moddate': '2025-10-28T12:02:29+00:00', 'trapped': '', 'modDate': "D:20251028120229+00'00'", 'creationDate': "D:20251028120230+00'00'", 'page': 13}, page_content='Homomorphic Encryption (HE)\nA cryptographic method that allows computations on encrypted data. \nCan perform calculations on it without decryption.\nThe server sees only encrypted file, but can still run functions (e.g., ML,\nstatistics, MFCC, Mel-Spectogram)\nAfter computation, the result is decrypted by the owner and matches the\noutput as if it was computed on original file.\n16'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-10-28T12:02:30+00:00', 'source': '../data/pdf/dp_presentation.pdf', 'file_path': '../data/pdf/dp_presentation.pdf', 'total_pages': 19, 'format': 'PDF 1.4', 'title': 'DP presentation', 'author': 'Sadman Sahil', 'subject': '', 'keywords': 'DAG2hyVnXFs,BAGndFZHqL4,0', 'moddate': '2025-10-28T12:02:29+00:00', 'trapped': '', 'modDate': "D:20251028120229+00'00'", 'creationDate': "D:20251028120230+00'00'", 'page': 14}, page_content='Homomorphic Encryption (HE)\n17'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-10-28T12:02:30+00:00', 'source': '../data/pdf/dp_presentation.pdf', 'file_path': '../data/pdf/dp_presentation.pdf', 'total_pages': 19, 'format': 'PDF 1.4', 'title': 'DP presentation', 'author': 'Sadman Sahil', 'subject': '', 'keywords': 'DAG2hyVnXFs,BAGndFZHqL4,0', 'moddate': '2025-10-28T12:02:29+00:00', 'trapped': '', 'modDate': "D:20251028120229+00'00'", 'creationDate': "D:20251028120230+00'00'", 'page': 15}, page_content='Limitations of Fully Homomorphic\nEncryption (FHE)\nFully Homomorphic Encryption only allows computation on low-bit integers\n(usually <= 16 bits)\nStandard audio processing (STFT, Mel, MFCC) uses floating-point math and produces\nlarge intermediate values inexecutable inside HE. \nSo direct manipulations (MFCC , Mels ) on encrypted audio would cause\n        overflow.\nIt adds noise after every operation as can not calculate exact precision value and has\nhigher computational cost.\n18'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-10-28T12:02:30+00:00', 'source': '../data/pdf/dp_presentation.pdf', 'file_path': '../data/pdf/dp_presentation.pdf', 'total_pages': 19, 'format': 'PDF 1.4', 'title': 'DP presentation', 'author': 'Sadman Sahil', 'subject': '', 'keywords': 'DAG2hyVnXFs,BAGndFZHqL4,0', 'moddate': '2025-10-28T12:02:29+00:00', 'trapped': '', 'modDate': "D:20251028120229+00'00'", 'creationDate': "D:20251028120230+00'00'", 'page': 16}, page_content='QASP (Quantized Approximate Signal\nProcessing)\n It basically converts the high presition continuous audio data to discrete low bit\nformat.\nDoes this By Quantization basically discretization of values so that higher\ncalculations done easily\nPreserve only the necessary audio structure for downstream tasks.\nThis discretization is achieved through agressive Quantization.\n19'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-10-28T12:02:30+00:00', 'source': '../data/pdf/dp_presentation.pdf', 'file_path': '../data/pdf/dp_presentation.pdf', 'total_pages': 19, 'format': 'PDF 1.4', 'title': 'DP presentation', 'author': 'Sadman Sahil', 'subject': '', 'keywords': 'DAG2hyVnXFs,BAGndFZHqL4,0', 'moddate': '2025-10-28T12:02:29+00:00', 'trapped': '', 'modDate': "D:20251028120229+00'00'", 'creationDate': "D:20251028120230+00'00'", 'page': 17}, page_content='Future Scope\n20'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-10-28T12:02:30+00:00', 'source': '../data/pdf/dp_presentation.pdf', 'file_path': '../data/pdf/dp_presentation.pdf', 'total_pages': 19, 'format': 'PDF 1.4', 'title': 'DP presentation', 'author': 'Sadman Sahil', 'subject': '', 'keywords': 'DAG2hyVnXFs,BAGndFZHqL4,0', 'moddate': '2025-10-28T12:02:29+00:00', 'trapped': '', 'modDate': "D:20251028120229+00'00'", 'creationDate': "D:20251028120230+00'00'", 'page': 18}, page_content='Possible Future Approach\nAnonymize the audio while keeping the privacy intact(tradeoff of EER & WER)\nExplore Homomorphic encryption technology\nKeep a key to reverse back to original version from anonymized one\n21')]
